# %% [markdown]
# # visualgorithm: a sorting machine problem
# ---
# *submitted by Goldy Mariz Lunesa || [@gmlunesa](https://github.com/gmlunesa)*
#
#
# ## O($n^{2}$)  algorithms
# - Best case comparison (pre sorted sequences)
#
# - Worst case comparison (reverse sorted sequences)
#
# - Average case comparison (random numbers)

# %%
# from Graphs import on2_eval, insertion_vs_shell, shell_vs_ciura, shell_vs_ciura_line, bucket_sort_eval, bucket_sort_eval_line, counting_vs_insertion_radix, merge_vs_quick

on2_eval()

# %% [markdown]
# ## Shell Sort optimization
#
# ### Shell Sort with Insertion Sort subroutine vs Insertion Sort
#
# - pre sorted sequences
#
# - reverse sorted sequences
#
# - random numbers

# %%
insertion_vs_shell()
# Out:
# True

# %% [markdown]
# ### Shell Sort using Shell's Gap Sequence vs Ciura's Gap Sequence
#
# #### Based on comparison count
# - pre sorted sequences
#
# - reverse sorted sequences
#
# - random numbers

# %%
shell_vs_ciura_line()

# %% [markdown]
# ---
#
# #### Based on unsortedness
#
# - pre sorted sequences
#
# - reverse sorted sequences
#
# - random numbers

# %%
shell_vs_ciura()

# %% [markdown]
# ## Bucket Sort
#
# ### Bucket sort comparisons on different distributions
# - Best Case distribution
# - Worst Case distribution
# - Random Case distribution

# %%
bucket_sort_eval_line()

# %% [markdown]
# ### Bucket sort elements on different distributions
# - Best Case distribution
# - Worst Case distribution
# - Random Case distribution

# %%
bucket_sort_eval()

# %% [markdown]
# ## Radix Sort
#
# ### Radix Sort with Counting Sort subroutine vs Radix Sort with Insertion Sort subroutine
# - pre sorted sequences
#
# - reverse sorted sequences
#
# - random numbers

# %%
counting_vs_insertion_radix()

# %% [markdown]
# ## Merge Sort and Quick Sort
# - Random numbers between 1 and 300
# - Random numbers between 1 and 100

# %%
merge_vs_quick()
# Out:
# [0, 0, 1, 3, 6, 10, 15, 21, 14, 17, 21, 23, 32, 49, 69, 62, 65, 77, 65, 61, 75, 67, 84, 74, 76, 84, 110, 106, 99, 99, 122, 126, 125, 126, 134, 159, 133, 201, 183, 194, 192, 232, 192, 219, 280, 279, 229, 227, 246, 260, 277, 296, 286, 244, 276, 273, 351, 314, 370, 306, 275, 313, 342, 303, 353, 334, 318, 342, 330, 366, 372, 419, 380, 420, 418, 427, 449, 451, 465, 467, 546, 492, 489, 488, 571, 581, 572, 632, 494, 539, 621, 613, 673, 731, 558, 680, 524, 571, 674, 694, 710, 695, 705, 757, 703, 727, 648, 754, 711, 783, 710, 697, 639, 715, 873, 820, 767, 909, 756, 786, 736, 756, 752, 833, 770, 789, 838, 813, 815, 912, 934, 1061, 1362, 1069, 922, 1197, 1016, 1026, 1117, 933, 922, 866, 968, 948, 990, 1017, 1047, 1184, 1019, 984, 1078, 1025, 1069, 1082, 1261, 1028, 1378, 1127, 1149, 1139, 1298, 1200, 1107, 1109, 1330, 1413, 1374, 1226, 1291, 1421, 1345, 1328, 1255, 1409, 1260, 1421, 1203, 1425, 1447, 1341, 1273, 1279, 1385, 1360, 1416, 1627, 1407, 1396, 1642, 1473, 1438, 1380, 1434, 1687, 1565,
# ...
